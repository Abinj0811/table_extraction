# %%
pdf = {'./app/images/M2-EQUIPMENT LIST IN ER-S1940/page_005.jpg': {'output_folder': 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_005', 'tables': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_005/page_005_table1.png'], 'components': []}, './app/images/M2-EQUIPMENT LIST IN ER-S1940/page_008.jpg': {'output_folder': 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_008', 'tables': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_008/page_008_table1.png'], 'components': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_008/page_008_title.png']}, './app/images/M2-EQUIPMENT LIST IN ER-S1940/page_007.jpg': {'output_folder': 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_007', 'tables': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_007/page_007_table1.png'], 'components': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_007/page_007_title.png']}, './app/images/M2-EQUIPMENT LIST IN ER-S1940/page_009.jpg': {'output_folder': 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_009', 'tables': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_009/page_009_table1.png'], 'components': []}, './app/images/M2-EQUIPMENT LIST IN ER-S1940/page_013.jpg': {'output_folder': 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_013', 'tables': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_013/page_013_table1.png'], 'components': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_013/page_013_title.png']}, './app/images/M2-EQUIPMENT LIST IN ER-S1940/page_004.jpg': {'output_folder': 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_004', 'tables': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_004/page_004_table1.png'], 'components': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_004/page_004_title.png']}, './app/images/M2-EQUIPMENT LIST IN ER-S1940/page_012.jpg': {'output_folder': 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_012', 'tables': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_012/page_012_table1.png'], 'components': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_012/page_012_title.png']}, './app/images/M2-EQUIPMENT LIST IN ER-S1940/page_006.jpg': {'output_folder': 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_006', 'tables': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_006/page_006_table1.png'], 'components': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_006/page_006_title.png']}, './app/images/M2-EQUIPMENT LIST IN ER-S1940/page_003.jpg': {'output_folder': 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_003', 'tables': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_003/page_003_table1.png'], 'components': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_003/page_003_title.png']}, './app/images/M2-EQUIPMENT LIST IN ER-S1940/page_001.jpg': {'output_folder': 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_001', 'tables': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_001/page_001_table1.png', 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_001/page_001_table2.png'], 'components': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_001/page_001_makers.png', 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_001/page_001_title.png', 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_001/page_001_dwg_no.png', 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_001/page_001_mk_name.png']}, './app/images/M2-EQUIPMENT LIST IN ER-S1940/page_011.jpg': {'output_folder': 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_011', 'tables': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_011/page_011_table1.png'], 'components': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_011/page_011_title.png']}, './app/images/M2-EQUIPMENT LIST IN ER-S1940/page_010.jpg': {'output_folder': 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_010', 'tables': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_010/page_010_table1.png'], 'components': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_010/page_010_title.png']}, './app/images/M2-EQUIPMENT LIST IN ER-S1940/page_002.jpg': {'output_folder': 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_002', 'tables': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_002/page_002_table1.png'], 'components': ['app/images/M2-EQUIPMENT LIST IN ER-S1940/page_002/page_002_title.png']}}

# %%
a = 'app/images/M2-EQUIPMENT LIST IN ER-S1940/page_012/page_012_title.png'

# %%
import os
if '_table' in os.path.basename(a):
    print(111111111111)

# %%
a= 'app/uploaded_pdfs/M2-EQUIPMENT LIST IN ER-S1940.pdf'

# %%
print(a.split('.pdf')[0])
# Out:
# app/uploaded_pdfs/M2-EQUIPMENT LIST IN ER-S1940
